# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa9391/BDI_CIAFR10/blob/Manasa/CNN_Experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTING KERAS AND CIFAR-10 DATASET

# %%
import numpy as np

from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical   


(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# ...
# 170500096/170498071 [==============================] - 120s 1us/step

# %%
print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %%
import matplotlib.pyplot as plt

cifar_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
print('Example training images and their labels: ' + str([x[0] for x in y_train[0:5]])) 
print('Corresponding classes for the labels: ' + str([cifar_classes[x[0]] for x in y_train[0:5]]))

f, axarr = plt.subplots(1, 5)
f.set_size_inches(16, 6)

for i in range(5):
    img = X_train[i]
    axarr[i].imshow(img)
plt.show()
# Out:
# Example training images and their labels: [6, 9, 9, 4, 1]
# Corresponding classes for the labels: ['frog', 'truck', 'truck', 'deer', 'automobile']

# %%
# A simple CNN Model fr CIFAR-10

# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa9391/BDI_CIFAR10/blob/master/VGG_Experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

class cifar10vgg:
    def __init__(self,train=True):
        self.num_classes = 10
        self.weight_decay = 0.0005
        self.x_shape = [32,32,3]

        self.model = self.build_model()
        if train:
            self.model = self.train(self.model)
        else:
            self.model.load_weights('cifar10vgg.h5')


    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.

        model = Sequential()
        weight_decay = self.weight_decay

        model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=self.x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

        model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Dropout(0.5))
        model.add(Dense(self.num_classes))
        model.add(Activation('softmax'))
        return model


    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        # Input: training set and test set
        # Output: normalized training set and test set according to the trianing set statistics.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    def normalize_production(self,x):
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 120.707
        std = 64.15
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)

    def train(self,model):

        #training parameters
        batch_size = 128
        maxepoches = 150
        learning_rate = 0.1
        lr_decay = 1e-6
        lr_drop = 20
        # The data, shuffled and split between train and test sets:
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train, x_test = self.normalize(x_train, x_test)

        y_train = keras.utils.to_categorical(y_train, self.num_classes)
        y_test = keras.utils.to_categorical(y_test, self.num_classes)

        def lr_scheduler(epoch):
            return learning_rate * (0.5 ** (epoch // lr_drop))
        reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

        #data augmentation
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)



        #optimization details
        sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])


        # training process in a for loop with learning rate drop every 25 epoches.

        historytemp = model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=maxepoches,
                            validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=2)
        model.save_weights('cifar10vgg.h5')
        return model
# Out:
# Using TensorFlow backend.

# %%
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    y_train = keras.utils.to_categorical(y_train, 10)
    y_test = keras.utils.to_categorical(y_test, 10)

    model = cifar10vgg()

    predicted_x = model.predict(x_test)
    residuals = np.argmax(predicted_x,1)!=np.argmax(y_test,1)

    loss = sum(residuals)/len(residuals)
    print("the validation 0/1 loss is: ",loss)
# Out:
# Epoch 1/150
#  - 80s - loss: 23.3225 - acc: 0.1779 - val_loss: 17.5035 - val_acc: 0.0993
# Epoch 2/150
#  - 73s - loss: 12.7238 - acc: 0.2451 - val_loss: 10.3597 - val_acc: 0.1332
# Epoch 3/150
#  - 72s - loss: 8.7417 - acc: 0.2164 - val_loss: 7.9002 - val_acc: 0.2516
# Epoch 4/150
#  - 72s - loss: 6.1787 - acc: 0.2920 - val_loss: 4.9664 - val_acc: 0.2503
# Epoch 5/150
#  - 72s - loss: 3.8354 - acc: 0.3591 - val_loss: 3.2863 - val_acc: 0.2889
# Epoch 6/150
#  - 72s - loss: 2.6748 - acc: 0.4217 - val_loss: 2.4957 - val_acc: 0.3866
# Epoch 7/150
#  - 72s - loss: 2.0540 - acc: 0.5026 - val_loss: 1.8230 - val_acc: 0.5484
# Epoch 8/150
#  - 72s - loss: 1.7211 - acc: 0.5732 - val_loss: 1.9013 - val_acc: 0.5292
# Epoch 9/150
#  - 72s - loss: 1.5778 - acc: 0.6139 - val_loss: 1.6118 - val_acc: 0.6343
# Epoch 10/150
#  - 72s - loss: 1.5306 - acc: 0.6436 - val_loss: 1.5513 - val_acc: 0.6501
# Epoch 11/150
#  - 72s - loss: 1.4818 - acc: 0.6698 - val_loss: 1.7228 - val_acc: 0.6181
# Epoch 12/150
#  - 72s - loss: 1.5015 - acc: 0.6787 - val_loss: 1.4453 - val_acc: 0.7116
# Epoch 13/150
#  - 72s - loss: 1.4944 - acc: 0.6982 - val_loss: 1.5093 - val_acc: 0.6990
# Epoch 14/150
#  - 72s - loss: 1.4602 - acc: 0.7102 - val_loss: 1.4584 - val_acc: 0.7108
# Epoch 15/150
#  - 72s - loss: 1.4591 - acc: 0.7149 - val_loss: 1.6146 - val_acc: 0.6595
# Epoch 16/150
#  - 72s - loss: 1.4568 - acc: 0.7197 - val_loss: 1.3716 - val_acc: 0.7466
# Epoch 17/150
#  - 72s - loss: 1.4614 - acc: 0.7233 - val_loss: 1.4236 - val_acc: 0.7272
# Epoch 18/150
#  - 72s - loss: 1.4636 - acc: 0.7256 - val_loss: 1.4174 - val_acc: 0.7396
# Epoch 19/150
#  - 72s - loss: 1.4740 - acc: 0.7278 - val_loss: 1.3769 - val_acc: 0.7563
# Epoch 20/150
#  - 72s - loss: 1.4695 - acc: 0.7323 - val_loss: 1.6447 - val_acc: 0.6942
# Epoch 21/150
#  - 72s - loss: 1.2989 - acc: 0.7731 - val_loss: 1.1603 - val_acc: 0.8039
# Epoch 22/150
#  - 72s - loss: 1.2031 - acc: 0.7837 - val_loss: 1.1465 - val_acc: 0.7955
# Epoch 23/150
#  - 72s - loss: 1.1826 - acc: 0.7849 - val_loss: 1.1674 - val_acc: 0.7865
# Epoch 24/150
#  - 72s - loss: 1.1742 - acc: 0.7852 - val_loss: 1.1545 - val_acc: 0.7949
# Epoch 25/150
#  - 72s - loss: 1.1780 - acc: 0.7870 - val_loss: 1.1025 - val_acc: 0.8152
# Epoch 26/150
#  - 72s - loss: 1.1870 - acc: 0.7851 - val_loss: 1.1956 - val_acc: 0.7831
# Epoch 27/150
#  - 72s - loss: 1.1852 - acc: 0.7898 - val_loss: 1.2485 - val_acc: 0.7750
# Epoch 28/150
#  - 72s - loss: 1.2037 - acc: 0.7879 - val_loss: 1.1134 - val_acc: 0.8191
# Epoch 29/150
#  - 72s - loss: 1.1955 - acc: 0.7941 - val_loss: 1.0967 - val_acc: 0.8297
# Epoch 30/150
#  - 72s - loss: 1.1906 - acc: 0.7947 - val_loss: 1.1208 - val_acc: 0.8188
# Epoch 31/150
#  - 72s - loss: 1.2000 - acc: 0.7956 - val_loss: 1.1165 - val_acc: 0.8217
# Epoch 32/150
#  - 72s - loss: 1.1997 - acc: 0.7989 - val_loss: 1.1074 - val_acc: 0.8274
# Epoch 33/150
#  - 72s - loss: 1.1996 - acc: 0.7979 - val_loss: 1.1490 - val_acc: 0.8179
# Epoch 34/150
#  - 72s - loss: 1.2018 - acc: 0.7990 - val_loss: 1.1625 - val_acc: 0.8127
# Epoch 35/150
#  - 72s - loss: 1.2040 - acc: 0.8007 - val_loss: 1.1141 - val_acc: 0.8281
# Epoch 36/150
#  - 72s - loss: 1.2107 - acc: 0.8011 - val_loss: 1.3469 - val_acc: 0.7743
# Epoch 37/150
#  - 72s - loss: 1.2193 - acc: 0.7998 - val_loss: 1.1328 - val_acc: 0.8220
# Epoch 38/150
#  - 72s - loss: 1.2136 - acc: 0.8025 - val_loss: 1.1809 - val_acc: 0.8095
# Epoch 39/150
#  - 72s - loss: 1.2095 - acc: 0.8052 - val_loss: 1.1180 - val_acc: 0.8332
# Epoch 40/150
#  - 72s - loss: 1.2094 - acc: 0.8048 - val_loss: 1.1503 - val_acc: 0.8247
# Epoch 41/150
#  - 72s - loss: 1.0867 - acc: 0.8364 - val_loss: 0.9576 - val_acc: 0.8671
# Epoch 42/150
#  - 72s - loss: 1.0116 - acc: 0.8449 - val_loss: 1.0036 - val_acc: 0.8441
# Epoch 43/150
#  - 72s - loss: 0.9719 - acc: 0.8485 - val_loss: 0.9063 - val_acc: 0.8653
# Epoch 44/150
#  - 72s - loss: 0.9583 - acc: 0.8464 - val_loss: 0.9264 - val_acc: 0.8539
# Epoch 45/150
#  - 72s - loss: 0.9467 - acc: 0.8455 - val_loss: 0.9739 - val_acc: 0.8386
# Epoch 46/150
#  - 72s - loss: 0.9475 - acc: 0.8443 - val_loss: 0.8705 - val_acc: 0.8664
# Epoch 47/150
#  - 72s - loss: 0.9446 - acc: 0.8465 - val_loss: 0.8537 - val_acc: 0.8757
# Epoch 48/150
#  - 72s - loss: 0.9391 - acc: 0.8460 - val_loss: 0.9183 - val_acc: 0.8556
# Epoch 49/150
#  - 72s - loss: 0.9442 - acc: 0.8462 - val_loss: 0.9602 - val_acc: 0.8439
# Epoch 50/150
#  - 72s - loss: 0.9447 - acc: 0.8459 - val_loss: 0.9310 - val_acc: 0.8475
# Epoch 51/150
#  - 72s - loss: 0.9432 - acc: 0.8482 - val_loss: 0.8625 - val_acc: 0.8731
# Epoch 52/150
#  - 72s - loss: 0.9441 - acc: 0.8494 - val_loss: 0.8853 - val_acc: 0.8636
# Epoch 53/150
#  - 72s - loss: 0.9431 - acc: 0.8476 - val_loss: 0.8641 - val_acc: 0.8737
# Epoch 54/150
#  - 72s - loss: 0.9349 - acc: 0.8516 - val_loss: 0.9397 - val_acc: 0.8555
# Epoch 55/150
#  - 72s - loss: 0.9427 - acc: 0.8487 - val_loss: 0.9086 - val_acc: 0.8576
# Epoch 56/150
#  - 72s - loss: 0.9444 - acc: 0.8487 - val_loss: 0.8749 - val_acc: 0.8733
# Epoch 57/150
#  - 72s - loss: 0.9502 - acc: 0.8474 - val_loss: 0.9031 - val_acc: 0.8655
# Epoch 58/150
#  - 72s - loss: 0.9511 - acc: 0.8475 - val_loss: 0.9282 - val_acc: 0.8587
# Epoch 59/150
#  - 72s - loss: 0.9429 - acc: 0.8526 - val_loss: 0.8813 - val_acc: 0.8757
# Epoch 60/150
#  - 72s - loss: 0.9477 - acc: 0.8522 - val_loss: 0.9103 - val_acc: 0.8648
# Epoch 61/150
#  - 72s - loss: 0.8664 - acc: 0.8751 - val_loss: 0.7958 - val_acc: 0.8946
# Epoch 62/150
#  - 72s - loss: 0.8133 - acc: 0.8835 - val_loss: 0.7606 - val_acc: 0.8994
# Epoch 63/150
#  - 72s - loss: 0.7870 - acc: 0.8871 - val_loss: 0.7556 - val_acc: 0.8962
# Epoch 64/150
#  - 72s - loss: 0.7769 - acc: 0.8864 - val_loss: 0.7535 - val_acc: 0.8935
# Epoch 65/150
#  - 72s - loss: 0.7601 - acc: 0.8882 - val_loss: 0.7370 - val_acc: 0.8939
# Epoch 66/150
#  - 72s - loss: 0.7527 - acc: 0.8888 - val_loss: 0.7280 - val_acc: 0.8971
# Epoch 67/150
#  - 72s - loss: 0.7477 - acc: 0.8879 - val_loss: 0.7474 - val_acc: 0.8868
# Epoch 68/150
#  - 72s - loss: 0.7437 - acc: 0.8862 - val_loss: 0.7447 - val_acc: 0.8864
# Epoch 69/150
#  - 72s - loss: 0.7370 - acc: 0.8871 - val_loss: 0.7577 - val_acc: 0.8846
# Epoch 70/150
#  - 72s - loss: 0.7385 - acc: 0.8868 - val_loss: 0.7336 - val_acc: 0.8878
# Epoch 71/150
#  - 72s - loss: 0.7366 - acc: 0.8872 - val_loss: 0.7338 - val_acc: 0.8884
# Epoch 72/150
#  - 72s - loss: 0.7300 - acc: 0.8881 - val_loss: 0.7576 - val_acc: 0.8817
# Epoch 73/150
#  - 72s - loss: 0.7246 - acc: 0.8905 - val_loss: 0.7347 - val_acc: 0.8883
# Epoch 74/150
#  - 72s - loss: 0.7285 - acc: 0.8880 - val_loss: 0.6976 - val_acc: 0.8956
# Epoch 75/150
#  - 72s - loss: 0.7319 - acc: 0.8863 - val_loss: 0.7053 - val_acc: 0.8931
# Epoch 76/150
#  - 72s - loss: 0.7219 - acc: 0.8890 - val_loss: 0.6941 - val_acc: 0.8999
# Epoch 77/150
#  - 72s - loss: 0.7230 - acc: 0.8899 - val_loss: 0.7238 - val_acc: 0.8903
# Epoch 78/150
#  - 72s - loss: 0.7294 - acc: 0.8872 - val_loss: 0.7375 - val_acc: 0.8882
# Epoch 79/150
#  - 72s - loss: 0.7312 - acc: 0.8884 - val_loss: 0.7164 - val_acc: 0.8941
# Epoch 80/150
#  - 72s - loss: 0.7272 - acc: 0.8883 - val_loss: 0.7208 - val_acc: 0.8928
# Epoch 81/150
#  - 72s - loss: 0.6750 - acc: 0.9065 - val_loss: 0.6540 - val_acc: 0.9110
# Epoch 82/150
#  - 72s - loss: 0.6361 - acc: 0.9151 - val_loss: 0.6446 - val_acc: 0.9112
# Epoch 83/150
#  - 72s - loss: 0.6241 - acc: 0.9154 - val_loss: 0.6453 - val_acc: 0.9118
# Epoch 84/150
#  - 72s - loss: 0.6122 - acc: 0.9171 - val_loss: 0.6274 - val_acc: 0.9134
# Epoch 85/150
#  - 72s - loss: 0.5956 - acc: 0.9210 - val_loss: 0.6319 - val_acc: 0.9105
# Epoch 86/150
#  - 72s - loss: 0.5951 - acc: 0.9173 - val_loss: 0.6106 - val_acc: 0.9137
# Epoch 87/150
#  - 72s - loss: 0.5851 - acc: 0.9203 - val_loss: 0.6340 - val_acc: 0.9067
# Epoch 88/150
#  - 72s - loss: 0.5831 - acc: 0.9197 - val_loss: 0.6218 - val_acc: 0.9089
# Epoch 89/150
#  - 72s - loss: 0.5797 - acc: 0.9186 - val_loss: 0.6079 - val_acc: 0.9126
# Epoch 90/150
#  - 72s - loss: 0.5706 - acc: 0.9200 - val_loss: 0.6291 - val_acc: 0.9053
# Epoch 91/150
#  - 72s - loss: 0.5715 - acc: 0.9196 - val_loss: 0.6120 - val_acc: 0.9074
# Epoch 92/150
#  - 72s - loss: 0.5683 - acc: 0.9180 - val_loss: 0.6204 - val_acc: 0.9033
# Epoch 93/150
#  - 72s - loss: 0.5644 - acc: 0.9202 - val_loss: 0.6034 - val_acc: 0.9104
# Epoch 94/150
#  - 72s - loss: 0.5599 - acc: 0.9196 - val_loss: 0.5753 - val_acc: 0.9168
# Epoch 95/150
#  - 72s - loss: 0.5610 - acc: 0.9196 - val_loss: 0.6004 - val_acc: 0.9120
# Epoch 96/150
#  - 72s - loss: 0.5612 - acc: 0.9178 - val_loss: 0.6060 - val_acc: 0.9090
# Epoch 97/150
#  - 72s - loss: 0.5579 - acc: 0.9194 - val_loss: 0.6240 - val_acc: 0.9027
# Epoch 98/150
#  - 72s - loss: 0.5531 - acc: 0.9184 - val_loss: 0.6270 - val_acc: 0.9011
# Epoch 99/150
#  - 72s - loss: 0.5511 - acc: 0.9208 - val_loss: 0.6099 - val_acc: 0.9051
# Epoch 100/150
#  - 72s - loss: 0.5485 - acc: 0.9206 - val_loss: 0.6145 - val_acc: 0.9037
# Epoch 101/150
#  - 72s - loss: 0.5159 - acc: 0.9311 - val_loss: 0.5588 - val_acc: 0.9205
# Epoch 102/150
#  - 72s - loss: 0.4945 - acc: 0.9361 - val_loss: 0.5588 - val_acc: 0.9198
# Epoch 103/150
#  - 72s - loss: 0.4828 - acc: 0.9408 - val_loss: 0.5517 - val_acc: 0.9245
# Epoch 104/150
#  - 72s - loss: 0.4781 - acc: 0.9395 - val_loss: 0.5497 - val_acc: 0.9210
# Epoch 105/150
#  - 72s - loss: 0.4723 - acc: 0.9405 - val_loss: 0.5610 - val_acc: 0.9187
# Epoch 106/150
#  - 72s - loss: 0.4638 - acc: 0.9426 - val_loss: 0.5625 - val_acc: 0.9180
# Epoch 107/150
#  - 72s - loss: 0.4535 - acc: 0.9443 - val_loss: 0.5480 - val_acc: 0.9203
# Epoch 108/150
#  - 72s - loss: 0.4595 - acc: 0.9411 - val_loss: 0.5397 - val_acc: 0.9198
# Epoch 109/150
#  - 72s - loss: 0.4535 - acc: 0.9414 - val_loss: 0.5401 - val_acc: 0.9228
# Epoch 110/150
#  - 72s - loss: 0.4553 - acc: 0.9418 - val_loss: 0.5324 - val_acc: 0.9214
# Epoch 111/150
#  - 72s - loss: 0.4479 - acc: 0.9426 - val_loss: 0.5379 - val_acc: 0.9199
# Epoch 112/150
#  - 72s - loss: 0.4414 - acc: 0.9443 - val_loss: 0.5373 - val_acc: 0.9207
# Epoch 113/150
#  - 72s - loss: 0.4418 - acc: 0.9422 - val_loss: 0.5176 - val_acc: 0.9243
# Epoch 114/150
#  - 72s - loss: 0.4370 - acc: 0.9445 - val_loss: 0.5496 - val_acc: 0.9162
# Epoch 115/150
#  - 72s - loss: 0.4320 - acc: 0.9451 - val_loss: 0.5237 - val_acc: 0.9206
# Epoch 116/150
#  - 72s - loss: 0.4338 - acc: 0.9438 - val_loss: 0.5310 - val_acc: 0.9213
# Epoch 117/150
#  - 72s - loss: 0.4340 - acc: 0.9416 - val_loss: 0.5276 - val_acc: 0.9238
# Epoch 118/150
#  - 72s - loss: 0.4259 - acc: 0.9446 - val_loss: 0.5332 - val_acc: 0.9212
# Epoch 119/150
#  - 72s - loss: 0.4246 - acc: 0.9444 - val_loss: 0.5189 - val_acc: 0.9232
# Epoch 120/150
#  - 72s - loss: 0.4282 - acc: 0.9440 - val_loss: 0.5168 - val_acc: 0.9224
# Epoch 121/150
#  - 72s - loss: 0.4041 - acc: 0.9509 - val_loss: 0.5107 - val_acc: 0.9261
# Epoch 122/150
#  - 72s - loss: 0.3879 - acc: 0.9562 - val_loss: 0.4940 - val_acc: 0.9291
# Epoch 123/150
#  - 72s - loss: 0.3830 - acc: 0.9565 - val_loss: 0.4885 - val_acc: 0.9303
# Epoch 124/150
#  - 72s - loss: 0.3805 - acc: 0.9571 - val_loss: 0.5024 - val_acc: 0.9277
# Epoch 125/150
#  - 72s - loss: 0.3769 - acc: 0.9589 - val_loss: 0.5127 - val_acc: 0.9256
# Epoch 126/150
#  - 72s - loss: 0.3730 - acc: 0.9578 - val_loss: 0.4910 - val_acc: 0.9292
# Epoch 127/150
#  - 72s - loss: 0.3703 - acc: 0.9582 - val_loss: 0.5089 - val_acc: 0.9259
# Epoch 128/150
#  - 72s - loss: 0.3636 - acc: 0.9598 - val_loss: 0.4934 - val_acc: 0.9292
# Epoch 129/150
#  - 72s - loss: 0.3641 - acc: 0.9605 - val_loss: 0.4968 - val_acc: 0.9274
# Epoch 130/150
#  - 72s - loss: 0.3625 - acc: 0.9604 - val_loss: 0.4832 - val_acc: 0.9303
# Epoch 131/150
#  - 72s - loss: 0.3596 - acc: 0.9607 - val_loss: 0.4860 - val_acc: 0.9290
# Epoch 132/150
#  - 72s - loss: 0.3500 - acc: 0.9626 - val_loss: 0.5033 - val_acc: 0.9258
# Epoch 133/150
#  - 72s - loss: 0.3499 - acc: 0.9621 - val_loss: 0.4981 - val_acc: 0.9262
# Epoch 134/150
#  - 72s - loss: 0.3518 - acc: 0.9612 - val_loss: 0.4949 - val_acc: 0.9281
# Epoch 135/150
#  - 72s - loss: 0.3460 - acc: 0.9625 - val_loss: 0.4905 - val_acc: 0.9268
# Epoch 136/150
#  - 72s - loss: 0.3478 - acc: 0.9610 - val_loss: 0.4931 - val_acc: 0.9272
# Epoch 137/150
#  - 72s - loss: 0.3484 - acc: 0.9608 - val_loss: 0.4735 - val_acc: 0.9276
# Epoch 138/150
#  - 72s - loss: 0.3430 - acc: 0.9629 - val_loss: 0.4981 - val_acc: 0.9266
# Epoch 139/150
#  - 72s - loss: 0.3436 - acc: 0.9618 - val_loss: 0.4884 - val_acc: 0.9274
# Epoch 140/150
#  - 72s - loss: 0.3418 - acc: 0.9615 - val_loss: 0.4716 - val_acc: 0.9312
# Epoch 141/150
#  - 72s - loss: 0.3318 - acc: 0.9645 - val_loss: 0.4685 - val_acc: 0.9325
# Epoch 142/150
#  - 72s - loss: 0.3224 - acc: 0.9684 - val_loss: 0.4716 - val_acc: 0.9326
# Epoch 143/150
#  - 72s - loss: 0.3151 - acc: 0.9684 - val_loss: 0.4715 - val_acc: 0.9322
# Epoch 144/150
#  - 72s - loss: 0.3177 - acc: 0.9688 - val_loss: 0.4616 - val_acc: 0.9352
# Epoch 145/150
#  - 72s - loss: 0.3151 - acc: 0.9697 - val_loss: 0.4635 - val_acc: 0.9348
# Epoch 146/150
#  - 72s - loss: 0.3110 - acc: 0.9702 - val_loss: 0.4732 - val_acc: 0.9303
# Epoch 147/150
#  - 72s - loss: 0.3075 - acc: 0.9712 - val_loss: 0.4672 - val_acc: 0.9336
# Epoch 148/150
#  - 72s - loss: 0.3093 - acc: 0.9707 - val_loss: 0.4684 - val_acc: 0.9332
# Epoch 149/150
#  - 72s - loss: 0.3095 - acc: 0.9700 - val_loss: 0.4688 - val_acc: 0.9319
# Epoch 150/150
#  - 72s - loss: 0.3039 - acc: 0.9717 - val_loss: 0.4604 - val_acc: 0.9358
# the validation 0/1 loss is:  0.0642
